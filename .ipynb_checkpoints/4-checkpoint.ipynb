# %% [markdown]
# # Module - 4

# %% [markdown]
# # Random Forest Algorithm

# %%
#import library packages
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=p.read_csv('demo1.csv')

# %%
data.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2021-08-08T02:53:19.071Z  61.595900 -146.301800  31.00  1.50      ml   NaN
# 1  2021-08-08T02:43:56.156Z  39.370000 -119.728200   2.40  1.20      ml  14.0
# 2  2021-08-08T02:41:28.900Z  35.943667 -117.728167   0.42  0.56      ml  10.0
# 3  2021-08-08T02:19:00.550Z  38.817501 -122.789833   2.98  0.35      md  10.0
# 4  2021-08-08T02:15:56.570Z  19.380501 -155.234161   1.69  2.15      ml  31.0
#
#      gap     dmin     rms  ...                   updated  \
# 0    NaN      NaN  0.9300  ...  2021-08-08T02:57:01.140Z
# 1   66.1  0.09600  0.1049  ...  2021-08-08T02:48:58.055Z
# 2  106.0  0.06326  0.1600  ...  2021-08-08T02:44:57.423Z
# 3  108.0  0.01043  0.0200  ...  2021-08-08T02:20:33.910Z
# 4   82.0      NaN  0.2600  ...  2021-08-08T02:21:26.220Z
#
#                               place        type horizontalError depthError  \
# 0     50 km SSE of Nelchina, Alaska  earthquake             NaN       0.20
# 1  9 km NW of Virginia City, Nevada  earthquake             NaN       1.00
# 2         16km E of Little Lake, CA  earthquake            0.35       1.41
# 3        5km NNW of The Geysers, CA  earthquake            0.41       0.98
# 4         6 km S of Volcano, Hawaii  earthquake            0.36       0.24
#
#    magError  magNst     status  locationSource magSource
# 0       NaN     NaN  automatic              ak        ak
# 1     0.320    12.0  automatic              nn        nn
# 2     0.122     4.0  automatic              ci        ci
# 3       NaN     1.0  automatic              nc        nc
# 4     0.610    17.0  automatic              hv        hv
#
# [5 rows x 22 columns]

# %%
data.shape
# Out:
# (14406, 22)

# %%
df = data.dropna()

# %%
df.head(10)
# Out:
#                         time   latitude   longitude  depth   mag magType  \
# 2   2021-08-08T02:41:28.900Z  35.943667 -117.728167   0.42  0.56      ml
# 5   2021-08-08T02:13:55.060Z  35.776833 -117.586667   7.88  1.04      ml
# 7   2021-08-08T01:57:36.060Z  33.680500 -116.730500  14.30  0.80      ml
# 10  2021-08-08T01:49:10.870Z  33.154000 -116.389167  -0.17  0.60      ml
# 12  2021-08-08T01:34:18.050Z  38.764332 -122.710671   1.56  0.86      md
# 15  2021-08-08T01:24:31.670Z  46.498000 -122.429667  17.48  1.52      ml
# 17  2021-08-08T01:12:55.740Z  38.542168 -119.524170   4.17  1.88      md
# 21  2021-08-08T00:27:08.320Z  33.401667 -116.341500  12.03  0.83      ml
# 24  2021-08-07T23:47:13.210Z  35.887833 -117.716500   2.43  1.03      ml
# 25  2021-08-07T23:43:08.100Z  40.314999 -124.339333  29.30  2.19      md
#
#      nst    gap      dmin   rms  ...                   updated  \
# 2   10.0  106.0  0.063260  0.16  ...  2021-08-08T02:44:57.423Z
# 5   17.0  129.0  0.039810  0.17  ...  2021-08-08T02:17:31.376Z
# 7   32.0   50.0  0.033480  0.15  ...  2021-08-08T02:01:09.832Z
# 10  14.0  189.0  0.384600  0.26  ...  2021-08-08T01:52:50.681Z
# 12  10.0  116.0  0.009697  0.04  ...  2021-08-08T01:35:55.520Z
# 15  20.0   72.0  0.111700  0.08  ...  2021-08-08T01:49:10.750Z
# 17   8.0  109.0  0.032620  0.07  ...  2021-08-08T01:16:14.797Z
# 21  19.0  104.0  0.047420  0.22  ...  2021-08-08T00:30:38.957Z
# 24  15.0  100.0  0.080460  0.20  ...  2021-08-07T23:50:54.658Z
# 25   8.0  318.0  0.042650  0.09  ...  2021-08-08T00:05:13.685Z
#
#                                place        type horizontalError depthError  \
# 2          16km E of Little Lake, CA  earthquake            0.35       1.41
# 5       16km W of Searles Valley, CA  earthquake            0.38       0.77
# 7             7km S of Idyllwild, CA  earthquake            0.28       0.39
# 10     11km S of Borrego Springs, CA  earthquake            1.84      31.61
# 12    2km SW of Anderson Springs, CA  earthquake            0.44       0.30
# 15  5 km SE of Mossyrock, Washington  earthquake            0.39       0.83
# 17       29km SE of Markleeville, CA  earthquake            0.60       0.80
# 21     16km N of Borrego Springs, CA  earthquake            0.60       1.23
# 24       18km ESE of Little Lake, CA  earthquake            0.31       0.46
# 25           5km WSW of Petrolia, CA  earthquake            3.82       3.41
#
#     magError  magNst     status  locationSource magSource
# 2   0.122000     4.0  automatic              ci        ci
# 5   0.156000    12.0  automatic              ci        ci
# 7   0.117000    20.0  automatic              ci        ci
# 10  0.205000     3.0  automatic              ci        ci
# 12  0.160000     4.0  automatic              nc        nc
# 15  0.142294    10.0   reviewed              uw        uw
# 17  0.260000     6.0  automatic              nc        nc
# 21  0.125000    17.0  automatic              ci        ci
# 24  0.160000    14.0  automatic              ci        ci
# 25  0.410000     2.0  automatic              nc        nc
#
# [10 rows x 22 columns]

# %%
df.shape
# Out:
# (7024, 22)

# %%
del df['time']
del df['updated']
del df['place']
del df['net']
del df['magSource']
del df['type']
del df['id']

# %%
df.duplicated()
# Out:
# 2        False
# 5        False
# 7        False
# 10       False
# 12       False
#          ...
# 14398    False
# 14399    False
# 14402    False
# 14403    False
# 14405    False
# Length: 7024, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# latitude           0
# longitude          0
# depth              0
# mag                0
# magType            0
# nst                0
# gap                0
# dmin               0
# rms                0
# horizontalError    0
# depthError         0
# magError           0
# magNst             0
# status             0
# locationSource     0
# dtype: int64

# %%
df.head(50)
# Out:
#       latitude   longitude      depth   mag magType   nst    gap      dmin  \
# 2    35.943667 -117.728167   0.420000  0.56      ml  10.0  106.0  0.063260
# 5    35.776833 -117.586667   7.880000  1.04      ml  17.0  129.0  0.039810
# 7    33.680500 -116.730500  14.300000  0.80      ml  32.0   50.0  0.033480
# 10   33.154000 -116.389167  -0.170000  0.60      ml  14.0  189.0  0.384600
# 12   38.764332 -122.710671   1.560000  0.86      md  10.0  116.0  0.009697
# 15   46.498000 -122.429667  17.480000  1.52      ml  20.0   72.0  0.111700
# 17   38.542168 -119.524170   4.170000  1.88      md   8.0  109.0  0.032620
# 21   33.401667 -116.341500  12.030000  0.83      ml  19.0  104.0  0.047420
# 24   35.887833 -117.716500   2.430000  1.03      ml  15.0  100.0  0.080460
# 25   40.314999 -124.339333  29.300000  2.19      md   8.0  318.0  0.042650
# 32   34.064667 -117.296500  12.140000  1.20      ml  30.0   50.0  0.096630
# 37   38.831165 -122.814499   2.550000  1.02      md  22.0   44.0  0.008494
# 38   35.954500 -117.683000   1.930000  2.10      ml  28.0   43.0  0.027270
# 46   38.787167 -122.764664   1.900000  0.50      md  11.0   84.0  0.013980
# 48   35.948667 -117.718667   2.390000  1.25      ml  19.0   47.0  0.055410
# 49   33.943167 -117.056333   3.250000  0.90      ml  25.0   35.0  0.066620
# 51   38.417000 -119.564835   6.970000  2.45      ml  15.0   92.0  0.093450
# 52   33.362333 -116.378000  11.520000  0.84      ml  22.0   52.0  0.057240
# 53   32.640833 -115.723333   6.980000  1.33      ml  13.0  198.0  0.008854
# 56   33.132000 -116.673333  16.120000  0.80      ml  20.0   55.0  0.070450
# 57   36.132667 -117.832667   2.470000  1.53      ml  16.0   97.0  0.023440
# 63   33.937667 -117.052500   2.960000  1.57      ml  59.0   43.0  0.061960
# 65   35.596667 -117.395000   8.880000  0.73      ml  11.0  164.0  0.055700
# 74   35.669667 -117.500667  10.420000  0.93      ml   8.0  176.0  0.088710
# 76   17.930800  -66.919500  13.000000  2.62      md  16.0  210.0  0.130600
# 84   33.439000 -116.890333   8.080000  0.39      ml  11.0   87.0  0.088260
# 86   38.774834 -122.718834   1.470000  1.46      md  23.0   87.0  0.014040
# 91   38.798168 -122.750664   1.480000  0.86      md  15.0   97.0  0.018460
# 93   32.870667 -115.980333   9.190000  0.81      ml  17.0   72.0  0.018640
# 97   33.722000 -116.836667  14.730000  0.50      ml  16.0  125.0  0.092230
# 98   37.517833 -118.500667   2.170000  0.96      md   8.0  121.0  0.054640
# 99   38.811165 -122.838997   0.430000  1.69      md   6.0  136.0  0.008007
# 101  38.828335 -122.804497   1.680000  0.33      md  10.0   76.0  0.006581
# 102  38.816166 -122.820503   2.440000  2.02      md  12.0   73.0  0.009952
# 104  32.920000 -115.945500   9.030000  1.05      ml  14.0  112.0  0.038620
# 108  39.671001 -122.888664   0.480000  3.20      ml  41.0   43.0  0.252000
# 109  37.538833 -118.455000   9.070000  0.94      md   4.0  125.0  0.013050
# 113  34.852167 -118.967333  10.460000  1.26      ml  19.0   75.0  0.073590
# 115  17.966800  -66.983600   5.000000  2.61      md  17.0  195.0  0.060700
# 117  48.316833 -121.886333  -0.490000  2.20      ml  25.0   50.0  0.124700
# 119  38.756000 -122.716003   1.590000  1.09      md   9.0  170.0  0.017850
# 131  33.675000 -116.756000  14.960000  0.48      ml  15.0   63.0  0.050180
# 136  40.378000 -121.309000   8.270000  0.84      md   8.0  136.0  0.089140
# 138  40.664166 -124.913330  -0.090000  2.45      md  30.0  273.0  0.477400
# 140  33.720667 -116.746500  16.270000  0.52      ml  15.0  146.0  0.028570
# 144  40.399500 -121.302500   6.460000  0.96      md   8.0  147.0  0.092170
# 147  35.673167 -117.500667   9.650000  0.82      ml  12.0  160.0  0.091980
# 149  33.366500 -116.370500  13.310000  0.43      ml  16.0   64.0  0.051130
# 154  17.934500  -66.831300  11.000000  2.37      md  11.0  206.0  0.215800
# 155  31.726128 -104.572575   6.157275  2.70      ml  19.0   85.0  0.056360
#
#       rms  horizontalError  depthError  magError  magNst     status  \
# 2    0.16          0.35000    1.410000  0.122000     4.0  automatic
# 5    0.17          0.38000    0.770000  0.156000    12.0  automatic
# 7    0.15          0.28000    0.390000  0.117000    20.0  automatic
# 10   0.26          1.84000   31.610000  0.205000     3.0  automatic
# 12   0.04          0.44000    0.300000  0.160000     4.0  automatic
# 15   0.08          0.39000    0.830000  0.142294    10.0   reviewed
# 17   0.07          0.60000    0.800000  0.260000     6.0  automatic
# 21   0.22          0.60000    1.230000  0.125000    17.0  automatic
# 24   0.20          0.31000    0.460000  0.160000    14.0  automatic
# 25   0.09          3.82000    3.410000  0.410000     2.0  automatic
# 32   0.18          0.28000    0.860000  0.144000    30.0  automatic
# 37   0.06          0.26000    0.630000  0.150000     3.0  automatic
# 38   0.17          0.21000    0.320000  0.163000    25.0  automatic
# 46   0.02          0.33000    0.850000  0.350000     2.0  automatic
# 48   0.16          0.22000    0.300000  0.120000    19.0  automatic
# 49   0.26          0.37000    1.090000  0.153000    27.0  automatic
# 51   0.08          0.31000    0.800000  0.344000     9.0  automatic
# 52   0.25          0.42000    0.860000  0.256000    19.0  automatic
# 53   0.19          0.80000    0.710000  0.264000    12.0  automatic
# 56   0.32          0.74000    1.300000  0.137000    13.0  automatic
# 57   0.11          0.27000    0.270000  0.239000    22.0  automatic
# 63   0.20          0.20000    0.450000  0.117000    26.0  automatic
# 65   0.17          0.60000    0.680000  0.118000     8.0  automatic
# 74   0.15          0.57000    0.990000  0.263000     9.0  automatic
# 76   0.26          0.90000    0.450000  0.210000    16.0   reviewed
# 84   0.19          0.48000    1.830000  0.067000     9.0  automatic
# 86   0.05          0.25000    0.360000  0.110000     9.0  automatic
# 91   0.02          0.26000    0.590000  0.240000     4.0  automatic
# 93   0.22          0.44000    0.710000  0.175000     7.0  automatic
# 97   0.17          0.48000    0.690000  0.139000    10.0  automatic
# 98   0.04          0.46000   31.610000  0.115000     8.0   reviewed
# 99   0.02          0.45000    0.590000  0.890000     2.0  automatic
# 101  0.01          0.37000    0.540000  0.350000     2.0  automatic
# 102  0.02          0.38000    0.890000  1.000000     2.0  automatic
# 104  0.23          0.57000    0.880000  0.160000    12.0  automatic
# 108  0.50          0.71000    6.030000  0.203000     6.0  automatic
# 109  0.06          1.07000    1.720000  0.422000     4.0   reviewed
# 113  0.25          0.49000    1.090000  0.226000    22.0  automatic
# 115  0.14          0.51000    0.280000  0.250000     6.0   reviewed
# 117  0.16          0.25000    0.780000  0.137846    14.0   reviewed
# 119  0.02          0.35000    0.580000  0.110000     4.0  automatic
# 131  0.19          0.49000    0.710000  0.066000     7.0  automatic
# 136  0.08          0.59000    0.860000  0.291000     8.0   reviewed
# 138  0.19          3.93000    5.920000  0.010000     2.0  automatic
# 140  0.11          0.29000    0.340000  0.177000    10.0   reviewed
# 144  0.05          0.61000    0.650000  0.183000     9.0   reviewed
# 147  0.17          0.51000    1.410000  0.154000    10.0  automatic
# 149  0.16          0.40000    0.780000  0.087000     4.0  automatic
# 154  0.08          0.52000    0.410000  0.130000     8.0   reviewed
# 155  0.30          1.63186    1.004077  0.200000     9.0   reviewed
#
#     locationSource
# 2               ci
# 5               ci
# 7               ci
# 10              ci
# 12              nc
# 15              uw
# 17              nc
# 21              ci
# 24              ci
# 25              nc
# 32              ci
# 37              nc
# 38              ci
# 46              nc
# 48              ci
# 49              ci
# 51              nc
# 52              ci
# 53              ci
# 56              ci
# 57              ci
# 63              ci
# 65              ci
# 74              ci
# 76              pr
# 84              ci
# 86              nc
# 91              nc
# 93              ci
# 97              ci
# 98              nc
# 99              nc
# 101             nc
# 102             nc
# 104             ci
# 108             nc
# 109             nc
# 113             ci
# 115             pr
# 117             uw
# 119             nc
# 131             ci
# 136             nc
# 138             nc
# 140             ci
# 144             nc
# 147             ci
# 149             ci
# 154             pr
# 155             tx

# %%
df.tail(100)
# Out:
#         latitude   longitude      depth   mag magType   nst    gap      dmin  \
# 14154  33.606000 -116.734833  13.090000  0.45      ml  27.0   71.0  0.027340
# 14159  38.498333 -119.510667   5.110000  2.43      md  15.0   89.0  0.057170
# 14162  31.949158 -102.027082  11.713826  1.50      ml  15.0   71.0  0.174144
# 14166  38.464333 -119.546667  -0.690000  2.57      md  16.0   83.0  0.094010
# 14171  38.814999 -122.824837   3.520000  0.64      md  10.0  184.0  0.006998
# ...          ...         ...        ...   ...     ...   ...    ...       ...
# 14398  38.512833 -119.512000   4.720000  2.55      md  13.0  104.0  0.058520
# 14399  38.511000 -119.538000   1.400000  2.52      md  15.0   98.0  0.078580
# 14402  35.826000 -117.656000   9.660000  0.33      ml   7.0  157.0  0.048630
# 14403  38.474833 -119.530167   3.500000  1.91      md  13.0   72.0  0.077940
# 14405  33.867500 -116.827667  13.100000  0.89      ml  43.0   37.0  0.042190
#
#         rms  horizontalError  depthError  magError  magNst     status  \
# 14154  0.12         0.160000    0.390000     0.243    12.0   reviewed
# 14159  0.06         0.190000    0.460000     0.190    40.0   reviewed
# 14162  0.20         1.659311    2.237863     0.100     9.0   reviewed
# 14166  0.04         0.140000    0.660000     0.246    52.0   reviewed
# 14171  0.02         0.770000    1.060000     0.060     3.0  automatic
# ...     ...              ...         ...       ...     ...        ...
# 14398  0.02         0.230000    0.740000     0.091    26.0   reviewed
# 14399  0.05         0.260000    1.060000     0.194    27.0   reviewed
# 14402  0.07         0.390000    0.890000     0.113     4.0   reviewed
# 14403  0.12         0.260000    1.010000     0.217    12.0   reviewed
# 14405  0.13         0.160000    0.400000     0.177    24.0   reviewed
#
#       locationSource
# 14154             ci
# 14159             nc
# 14162             tx
# 14166             nc
# 14171             nc
# ...              ...
# 14398             nc
# 14399             nc
# 14402             ci
# 14403             nc
# 14405             ci
#
# [100 rows x 15 columns]

# %%
df.magType.unique()
# Out:
# array(['ml', 'md', 'mlr'], dtype=object)

# %%
df.status.unique()
# Out:
# array(['automatic', 'reviewed'], dtype=object)

# %%
df.locationSource.unique()
# Out:
# array(['ci', 'nc', 'uw', 'pr', 'tx', 'uu', 'mb', 'se', 'nm'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['magType','status', 'locationSource']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
df.magType.unique()
# Out:
# array([1, 0, 2])

# %%
df.status.unique()
# Out:
# array([0, 1])

# %%
df.locationSource.unique()
# Out:
# array([0, 2, 8, 4, 6, 7, 1, 5, 3])

# %%
#preprocessing, split test and dataset, split response variable
X = df.drop(labels='status', axis=1)
#Response variable
y = df.loc[:,'status']

# %%
'''We'll use a test size of 20%. We also stratify the split on the response variable,
which is very important to do because there are so few fraudulent transactions'''

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1, stratify=y)
print("Number of training dataset: ", len(X_train))
print("Number of test dataset: ", len(X_test))
print("Total number of dataset: ", len(X_train)+len(X_test))
# Out:
# Number of training dataset:  5619
# Number of test dataset:  1405
# Total number of dataset:  7024

# %%
#According to the cross-validated MCC scores, the random forest is the best-performing model, so now let's evaluate its performance on the test set.
from sklearn.metrics import confusion_matrix, classification_report, matthews_corrcoef, cohen_kappa_score, accuracy_score, average_precision_score, roc_auc_score

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

rfc= RandomForestClassifier()

rfc.fit(X_train,y_train)

predictRF = rfc.predict(X_test)

print("")
print('Classification report of Random Forest Results:')
print("")
print(classification_report(y_test,predictRF))

print("")
cm1=confusion_matrix(y_test,predictRF)
print('Confusion Matrix result of Random Forest Classifier is:\n',cm1)
print("")
sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Sensitivity : ', sensitivity1 )
print("")
specificity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Specificity : ', specificity1)
print("")

accuracy = cross_val_score(rfc, X, y, scoring='accuracy')
print('Cross validation test results of accuracy:')
print(accuracy)
#get the mean of each fold 
print("")
print("Accuracy result of Random Forest Classifier is:",accuracy.mean() * 100)
RF=accuracy.mean() * 100
# Out:
# Classification report of Random Forest Results:
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.77      0.86       130
#            1       0.98      1.00      0.99      1275
#
#     accuracy                           0.98      1405
#    macro avg       0.98      0.88      0.92      1405
# weighted avg       0.98      0.98      0.98      1405
#
#
# Confusion Matrix result of Random Forest Classifier is:
#  [[ 100   30]
#  [   2 1273]]
#
# Sensitivity :  0.7692307692307693
#
# Specificity :  0.9984313725490196
#
# Cross validation test results of accuracy:
# [0.9366548  0.94519573 0.9886121  0.97295374 0.97008547]
#
# Accuracy result of Random Forest Classifier is: 96.27003680384463

# %%
def graph():
    import matplotlib.pyplot as plt
    data=[RF]
    alg="Random Forest Classifier"
    plt.figure(figsize=(5,5))
    b=plt.bar(alg,data,color=("m"))
    plt.title("Accuracy comparison of Earth Quake",fontsize=15)
    plt.legend(b,data,fontsize=9)

# %%
graph()

# %%
TP = cm1[0][0]
FP = cm1[1][0]
FN = cm1[1][1]
TN = cm1[0][1]
print("True Positive :",TP)
print("True Negative :",TN)
print("False Positive :",FP)
print("False Negative :",FN)
print("")
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(FP+TN)
FNR = FN/(TP+FN)
print("True Positive Rate :",TPR)
print("True Negative Rate :",TNR)
print("False Positive Rate :",FPR)
print("False Negative Rate :",FNR)
print("")
PPV = TP/(TP+FP)
NPV = TN/(TN+FN)
print("Positive Predictive Value :",PPV)
print("Negative predictive value :",NPV)
# Out:
# True Positive : 100
# True Negative : 30
# False Positive : 2
# False Negative : 1273
#
# True Positive Rate : 0.07283321194464676
# True Negative Rate : 0.9375
# False Positive Rate : 0.0625
# False Negative Rate : 0.9271667880553532
#
# Positive Predictive Value : 0.9803921568627451
# Negative predictive value : 0.023023791250959325

# %%
def plot_confusion_matrix(cm1, title='Confusion matrix-RandomForestClassifier', cmap=plt.cm.Blues):
    target_names=['Predict','Actual']
    plt.imshow(cm1, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = n.arange(len(target_names))
    plt.xticks(tick_marks, target_names, rotation=45)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

cm1=confusion_matrix(y_test, predictRF)
print('Confusion matrix-RandomForestClassifier:')
print(cm1)
plot_confusion_matrix(cm1)
# Out:
# Confusion matrix-RandomForestClassifier:
# [[ 100   30]
#  [   2 1273]]

# %% [markdown]
# # Creating pkl File

# %%
import joblib
joblib.dump(rfc,"rf.pkl")
# Out:
# ['rf.pkl']
